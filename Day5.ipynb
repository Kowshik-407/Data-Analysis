# %%
import pandas as pd

# %%
print(dir(pd))
# Out:
# ['BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__getattr__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_hashtable', '_lib', '_libs', '_np_version_under1p14', '_np_version_under1p15', '_np_version_under1p16', '_np_version_under1p17', '_np_version_under1p18', '_testing', '_tslib', '_typing', '_version', 'api', 'arr
# ...

# %%
data = pd.read_csv('Market.csv')

# %% [markdown]
# # Summarizing Data

# %%
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
data.head(7)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38
# 5   -47.64           6.15                 0.37
# ...

# %%
data.tail(7)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8392  Ord_5384   Prod_9  SHP_7519  Cust_1798   181.5000      0.08
# 8393  Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8392              43   -6.24           2.50                 0.37
# 8393               9   12.61           1.99                 0.44
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# ...

# %%
data.sample() # Random row
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 7262  Ord_3507  Prod_8  SHP_4858  Cust_1179  799.84      0.08              26
#
#       Profit  Shipping_Cost  Product_Base_Margin
# 7262   64.13            3.6                 0.64

# %%
data.sample(3)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  \
# 3792  Ord_1817   Prod_6  SHP_2621   Cust_662  342.27      0.09
# 1056  Ord_4514  Prod_17  SHP_6284  Cust_1457  124.19      0.03
# 4473  Ord_3259   Prod_9  SHP_4520  Cust_1217  299.08      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 3792               8  -17.68          19.99                 0.36
# 1056               7  -53.30          11.28                 0.38
# 4473               3  -50.43          19.99                 0.40

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
data.keys()
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
data.shape
# Out:
# (8399, 10)

# %%
data.size
# Out:
# 83990

# %% [markdown]
# # Statistical Analysis on data

# %%
data.info
# Out:
# <bound method DataFrame.info of         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %% [markdown]
# # Identifying the missing values

# %%
data.isnull()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394   False    False    False    False  False     False           False
# 8395   False    False    False    False  False     False           False
# 8396   False    False    False    False  False     False           False
# 8397   False    False    False    False  False     False           False
# 8398   False    False    False    False  False     False           False
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
data.notnull()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0       True     True     True     True   True      True            True
# 1       True     True     True     True   True      True            True
# 2       True     True     True     True   True      True            True
# 3       True     True     True     True   True      True            True
# 4       True     True     True     True   True      True            True
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394    True     True     True     True   True      True            True
# 8395    True     True     True     True   True      True            True
# 8396    True     True     True     True   True      True            True
# 8397    True     True     True     True   True      True            True
# 8398    True     True     True     True   True      True            True
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
data.isna()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394   False    False    False    False  False     False           False
# 8395   False    False    False    False  False     False           False
# 8396   False    False    False    False  False     False           False
# 8397   False    False    False    False  False     False           False
# 8398   False    False    False    False  False     False           False
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
data.notna()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0       True     True     True     True   True      True            True
# 1       True     True     True     True   True      True            True
# 2       True     True     True     True   True      True            True
# 3       True     True     True     True   True      True            True
# 4       True     True     True     True   True      True            True
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394    True     True     True     True   True      True            True
# 8395    True     True     True     True   True      True            True
# 8396    True     True     True     True   True      True            True
# 8397    True     True     True     True   True      True            True
# 8398    True     True     True     True   True      True            True
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
data.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 63

# %%
data.isnull().sum().sum().sum()
# Out:
# 63

# %%
data.isna().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %% [markdown]
# # Indexing
#
# 1. Selecting row: data[start:stop]
# 2. Selecting col: data{col_name] or data.col_name
# 3. Selecting multiple col : data[['col_name1','col_name2']]

# %%
data.head(3)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59

# %%
data['Discount'].head(3)
# Out:
# 0    0.01
# 1    0.01
# 2    0.00
# Name: Discount, dtype: float64

# %%
data[['Discount','Cust_id']].head()
# Out:
#    Discount    Cust_id
# 0      0.01  Cust_1818
# 1      0.01  Cust_1818
# 2      0.00  Cust_1818
# 3      0.09  Cust_1818
# 4      0.08  Cust_1818

# %%
data[['Discount','Cust_id']][1:5]
# Out:
#    Discount    Cust_id
# 1      0.01  Cust_1818
# 2      0.00  Cust_1818
# 3      0.09  Cust_1818
# 4      0.08  Cust_1818

# %% [markdown]
# # Filtering

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data['Sales'] > 45000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
data[data['Sales'] > 45000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 2738              13  27220.69          24.49                 0.39
# 3784               7    102.61          24.49                 0.39

# %%
(data['Sales'] > 35000) & (data['Sales'] < 45000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
data[(data['Sales'] > 35000) & (data['Sales'] < 45000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 1835               8  3852.19          24.49                 0.39

# %% [markdown]
# # Combining

# %%
dict1 = {'Name':['Kowshik407','Aravind415','Sridhar405'],
        'Branch':['CSE','ECE','CSSE']}
df1 = pd.DataFrame(dict1)
df1
# Out:
#          Name Branch
# 0  Kowshik407    CSE
# 1  Aravind415    ECE
# 2  Sridhar405   CSSE

# %%
dict2 = {'Name':['Jassu434','Triyekh436','Teja447'],
        'Branch':['MECH','CIVIL','IT']}
df2 = pd.DataFrame(dict2)
df2
# Out:
#          Name Branch
# 0    Jassu434   MECH
# 1  Triyekh436  CIVIL
# 2     Teja447     IT

# %%
pd.concat([df1,df2])
# Out:
#          Name Branch
# 0  Kowshik407    CSE
# 1  Aravind415    ECE
# 2  Sridhar405   CSSE
# 0    Jassu434   MECH
# 1  Triyekh436  CIVIL
# 2     Teja447     IT

# %% [markdown]
# - axis = 0  --> It represent rows
# - axis = 1  --> It represent cols

# %%
pd.concat([df1,df2], axis = 1)
# Out:
#          Name Branch        Name Branch
# 0  Kowshik407    CSE    Jassu434   MECH
# 1  Aravind415    ECE  Triyekh436  CIVIL
# 2  Sridhar405   CSSE     Teja447     IT

# %% [markdown]
# # Sorting

# %% [markdown]
# - ascending  order
# - descending order

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.sort_values(by=['Discount'], inplace=False)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.690      0.00
# 837   Ord_4764   Prod_6  SHP_6643  Cust_1622    32.690      0.00
# 839   Ord_1891  Prod_13  SHP_2597   Cust_682   157.870      0.00
# 783   Ord_2666   Prod_4  SHP_3652  Cust_1017  2368.168      0.00
# 860    Ord_289   Prod_3   SHP_390    Cust_67    51.210      0.00
# ...        ...      ...       ...        ...       ...       ...
# 5329   Ord_876   Prod_5  SHP_1204   Cust_299   586.110      0.11
# 5326   Ord_960   Prod_5  SHP_1329   Cust_349   651.900      0.16
# 5334   Ord_916   Prod_5  SHP_1262   Cust_328    27.960      0.17
# 7705   Ord_162   Prod_5   SHP_219    Cust_42   338.520      0.21
# 7713    Ord_13  Prod_11    SHP_17    Cust_12   663.784      0.25
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 8398              47   131.39           4.86                 0.38
# ...

# %%
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 7713    Ord_13  Prod_11    SHP_17    Cust_12   663.784      0.25
# 7705   Ord_162   Prod_5   SHP_219    Cust_42   338.520      0.21
# 5334   Ord_916   Prod_5  SHP_1262   Cust_328    27.960      0.17
# 5326   Ord_960   Prod_5  SHP_1329   Cust_349   651.900      0.16
# 5329   Ord_876   Prod_5  SHP_1204   Cust_299   586.110      0.11
# ...        ...      ...       ...        ...       ...       ...
# 7747  Ord_4999  Prod_17  SHP_6977  Cust_1698  9920.850      0.00
# 7722  Ord_1646  Prod_13  SHP_2273   Cust_490    55.330      0.00
# 7703   Ord_147  Prod_15   SHP_198    Cust_42  3758.770      0.00
# 7663  Ord_3524   Prod_8  SHP_4878  Cust_1181   368.170      0.00
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.690      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 7713              11  -481.04          69.00                 0.68
# ...
